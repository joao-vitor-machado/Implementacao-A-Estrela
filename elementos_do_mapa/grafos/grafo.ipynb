# %%
import networkx as nx

G = nx.read_edgelist('./cidades.txt', delimiter =",", data=[("distancia_real", int), ("velocidade_maxima", int)])

fig = nx.draw_networkx(G, width = 1.5)

# %%
euclidianas = {
    'Assis': 118,
    'Marilia': 149,
    'Aracatuba': 143,
    'Fernandopolis': 237,
    'SJRP': 254,
    'Barretos': 340,
    'Franca': 451,
    'Ribeirao_Preto': 385,
    'Araraquara': 333,
    'Sao_Carlos': 361,
    'Bauru': 241,
    'Botucatu': 313,
    'SJBV': 474,
    'Mogi_Mirim': 457,
    'Limeira': 413,
    'Piracicaba': 390,
    'Itapeva': 327,
    'Sorocaba': 431,
    'Campinas': 453,
    'Jundiai': 478,
    'SP': 511,
    'Guarulhos': 521,
    'Registro': 448,
    'Itanhaem': 523,
    'Santos': 557,
    'SJC': 577,
    'Taubate': 608
}

G.nodes['Taubate']['euclidianas'] = euclidianas

# %%
taubate = get_node_attributes(G, 'Taubate')
taubate['euclidianas']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_31414/1713476403.py in <module>
# ----> 1 taubate = get_node_attributes(G, 'Taubate')
#       2 taubate['euclidianas']
#
# NameError: name 'get_node_attributes' is not defined
